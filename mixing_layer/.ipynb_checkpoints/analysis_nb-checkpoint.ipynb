# %% [markdown]
# # Definitions

# %% [markdown]
# ## Import packages

# %%
import numpy as np
from matplotlib import pyplot as plt
import yt
import seaborn as sns

plt.style.use('../plot_scripts/plot_style.mplstyle')
# Out:
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:769: MatplotlibDeprecationWarning: The global colormaps dictionary is no longer considered public API.
#   self[key]

# %%
from yt import derived_field

CONST_pc  = 3.086e18
CONST_yr  = 3.154e7
CONST_amu = 1.66053886e-24
CONST_kB  = 1.3806505e-16
unit_length = CONST_pc*1e3  # 1 kpc
unit_time   = CONST_yr*1e6  # 1 Myr
unit_density = CONST_amu    # 1 mp/cm-3
unit_velocity = unit_length/unit_time
KELVIN = unit_velocity*unit_velocity*CONST_amu/CONST_kB

g = 5/3
# T_floor = 10000.0
T_ceil = 1e8

X = 1.0
Y = 0.0
Z = 0.0

mu = 1.0/(2.*X+ 3.*(1.-X-Z)/4.+ Z/2.)
mue = 2.0/(1.0+X)
muH = 1.0/X
mH = 1.0


# Temperature in Kelvin
@derived_field(name="temp", units="code_length**3*code_pressure/code_mass", \
    sampling_type="cell",force_override=True)
def _temp(field, data):
    return (data["gas", "pressure"] / data["gas", "density"]) * KELVIN * mu

# %%
def get_array(fn, MHD_flag = False):

    ds = yt.load(fn)

    all_data_level_0_hyd = ds.covering_grid(
        level=0, left_edge=[0, 0.0, 0.0], dims=ds.domain_dimensions
    )

    out_dict = {}

    x_arr = np.array(all_data_level_0_hyd[('gas','x')])
    y_arr = np.array(all_data_level_0_hyd[('gas','y')])
    z_arr = np.array(all_data_level_0_hyd[('gas','z')])

    r_arr = [x_arr,y_arr,z_arr]

    out_dict['coord'] = r_arr

    rho_arr  = np.array(all_data_level_0_hyd["density"])
    P_arr    = np.array(all_data_level_0_hyd["press"])
    T_arr    = np.array(all_data_level_0_hyd["temp"])
    
    out_dict['rho'] = rho_arr
    out_dict['T']   = T_arr
    out_dict['P']   = P_arr

    vel1_arr = np.array(all_data_level_0_hyd["vel1"])
    vel2_arr = np.array(all_data_level_0_hyd["vel2"])
    vel3_arr = np.array(all_data_level_0_hyd["vel3"])

    vel = [vel1_arr, vel2_arr, vel3_arr]

    out_dict['vel'] = vel

    if MHD_flag:
        Bcc1 = np.array(all_data_level_0_hyd["Bcc1"])
        Bcc2 = np.array(all_data_level_0_hyd["Bcc2"])
        Bcc3 = np.array(all_data_level_0_hyd["Bcc3"])

        Bcc = [Bcc1,Bcc2,Bcc3]

        out_dict['B'] = Bcc

    return out_dict

# %% [markdown]
# ## Class hst_data definitions

# %%
class hst_data:

    def __init__(self, fn, ncells, MHD_flag=False):

        """Read hst and return structured numpy dict.
        Keyword Arguments:
        fn -- 
        """

        hdr = []
        with open(fn, 'r') as fp:
            while True:
                l = fp.readline()
                if l[0] != '#':
                    raise Exception("No header in %s found!" %(fn))
                if '[1]' in l:
                    hdr = [i.split("=")[1].strip() for i in l[1:].split("[") if ']' in i]
                    break

        r = np.loadtxt(fn, dtype={'names' : hdr, 'formats' : len(hdr) * (float,)})

        self.dict = r

        self.time  = self.dict['time']
        self.dt    = self.dict['dt']

        self.mass_tot  = self.dict['mass']

        self.mom1  = self.dict['1-mom']
        self.mom2  = self.dict['2-mom']
        self.mom3  = self.dict['3-mom']

        self.KE1   = self.dict['1-KE']
        self.KE2   = self.dict['2-KE']
        self.KE3   = self.dict['3-KE']
        self.E_tot = self.dict['tot-E']

        self.cold_gas = self.dict['cold_gas']

        self.rho_avg    = self.dict['rho_sum']/ncells
        self.rho_sq_avg = self.dict['rho_sq_sum']/ncells

        self.cs_avg    = self.dict['c_s_sum']/ncells
        self.tcool_avg = self.dict['tcool_sum']/ncells

        if MHD_flag:

            self.Pth_avg = self.dict['Pth_sum']/ncells
            self.PB_avg  = self.dict['PB_sum']/ncells
            self.Bx_avg  = self.dict['Bx_sum']/ncells
            self.By_avg  = self.dict['By_sum']/ncells
            self.Bz_avg  = self.dict['Bz_sum']/ncells

            self.B_abs_avg = np.sqrt(self.PB_avg*2)
            self.dB = np.roll(self.B_abs_avg,-1) - self.B_abs_avg
            self.dt = self.time[1] - self.time[0]


        self.KE_tot = self.KE1+self.KE2+self.KE3
        self.turb_vel = np.sqrt(self.KE_tot*2/self.mass_tot)

        self.clumping_factor = self.rho_sq_avg/self.rho_avg**2
        self.cold_gas_fraction = self.cold_gas/self.mass_tot

# %%
# dirname = 'test_sechs_Bx_cool'
# dirname = 'test_seben_By_cool'
# dirname = 'test_acht_Bz_cool'
# dirname = 'test_neun_hyd_cool'

# dirname = 'test_zehn_Bx_cool_reflBC'
# dirname = 'test_elf_By_cool_reflBC'
dirname = 'test_zwolf_Bz_cool_reflBC'
# dirname = 'test_dreizehn_hyd_cool_reflBC'

N = 1

file_name = dirname + f'/Turb.out2.{str(N).zfill(5)}.athdf'

# print(ps.out_dt_arr[3]/ps.t_eddy[3])

ds = yt.load(file_name)
print(ds.field_list)

# p = yt.ProjectionPlot(ds,axis='x',fields="Bcc3")
p = yt.SlicePlot(ds,axis='y',fields="Bcc3")
# p = yt.ProjectionPlot(ds,axis='y',fields="temp")
# p.annotate_streamlines(('Bcc3'),('Bcc1'))
# p.annotate_streamlines(('Bcc2'),('Bcc3'))
# p.annotate_streamlines(('vel3'),('vel1'))

p.set_figure_size(20)

# p.set_zlim("vel3",-1e-1,1e-1)
# p.set_zlim("temp",4e4,4*1e6)
# p.set_zlim("temp",1e5,2e5)
# p.set_zlim("Bcc3", 0.001, 0.04)
# p.set_zlim("press",5*1e-4, 1e-1)

# p.set_zlim("density",1e-1, 1e2)

# # p.save('../plot_scripts/magnetic_field_lines_Rlsh_100_res_128_beta_100.png')

p.show()
# Out:
# yt : [WARNING  ] 2022-05-21 20:11:54,045 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 20:11:54,050 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 20:11:54,055 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 20:11:54,059 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 20:11:54,096 Parameters: current_time              = 1.0002837701780583
# yt : [INFO     ] 2022-05-21 20:11:54,096 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 20:11:54,098 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 20:11:54,099 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 20:11:54,100 Parameters: cosmological_simulation   = 0.0
# [('athena_pp', 'Bcc1'), ('athena_pp', 'Bcc2'), ('athena_pp', 'Bcc3'), ('athena_pp', 'press'), ('athena_pp', 'rho'), ('athena_pp', 'vel1'), ('athena_pp', 'vel2'), ('athena_pp', 'vel3')]
# yt : [INFO     ] 2022-05-21 20:11:58,455 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 20:11:58,458 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 20:11:58,463 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 20:11:58,466 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 20:11:58,471 Making a fixed resolution buffer of (('athena_pp', 'Bcc3')) 800 by 800
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>

# %%
import athena_read as ar

M_lim = 31

for M in range(M_lim):

        data_user = ar.athdf(dirname + f'/Turb.out4.{str(M).zfill(5)}.athdf')
        data_prim = ar.athdf(dirname + f'/Turb.out2.{str(M).zfill(5)}.athdf')

        temp = (data_prim['press'] / data_prim['rho']) * KELVIN * mu

        # print(np.shape(temp))
        # print(np.shape(data_user['user_out_var0']))

        # plt.figure()
        # plt.imshow(np.log10(data_user['user_out_var0'][:,32,:]))
        # plt.colorbar()

        x_arr = np.ravel(data_user['user_out_var0'])
        y_arr = np.ravel(temp)

        x_arr = np.log10(x_arr)
        y_arr = np.log10(y_arr)

        H, xedges, yedges = np.histogram2d(x_arr, y_arr, bins=1000)#, weights=out_dict_0['rho'])
        H = H.T

        plt.figure(figsize=(10,10))
        plt.imshow(np.log10(H), interpolation='nearest', origin='lower',
                extent=[-5, 1, 4.5, 6.6])

        plt.xlabel(r'log$_{10}$ tcool (Myr)')
        plt.ylabel(r'log$_{10}$ T (K)')

        plt.title(f'i: {M}')

        # plt.colorbar()
        plt.axhline(6, linestyle='dashed')

        plt.savefig(dirname + f'/Plots/T_tcool_{str(M).zfill(5)}.png')

        plt.close()

        print(M)
# plt.plot(hist_T[1][:-1], hist_T[0])
# plt.xscale('log')
# plt.yscale('log')
# Out:
# 0
# 1
# 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_14052/489498505.py in <module>
#      27
#      28         plt.figure(figsize=(10,10))
# ---> 29         plt.imshow(np.log10(H), interpolation='nearest', origin='lower',
#      30                 extent=[-5, 1, 4.5, 6.6])
#      31
#
# /afs/mpa/data/hitesh/envs/athenaenv/lib/python3.9/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /afs/mpa/data/hitesh/envs/athenaenv/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /afs/mpa/data/hitesh/envs/athenaenv/lib/python3.9/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5517             aspect = rcParams['image.aspect']
#    5518         self.set_aspect(aspect)
# -> 5519         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    5520                               filternorm=filternorm, filterrad=filterrad,
#    5521                               resample=resample, **kwargs)
#
# /afs/mpa/data/hitesh/envs/athenaenv/lib/python3.9/site-packages/matplotlib/image.py in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     900         self._extent = extent
#     901
# --> 902         super().__init__(
#     903             ax,
#     904             cmap=cmap,
#
# /afs/mpa/data/hitesh/envs/athenaenv/lib/python3.9/site-packages/matplotlib/image.py in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     241                  ):
#     242         martist.Artist.__init__(self)
# --> 243         cm.ScalarMappable.__init__(self, norm, cmap)
#     244         if origin is None:
#     245             origin = mpl.rcParams['image.origin']
#
# /afs/mpa/data/hitesh/envs/athenaenv/lib/python3.9/site-packages/matplotlib/cm.py in __init__(self, norm, cmap)
#     237         #: The last colorbar associated with this ScalarMappable. May be None.
#     238         self.colorbar = None
# --> 239         self.callbacksSM = cbook.CallbackRegistry()
#     240         self._update_dict = {'array': False}
#     241
#
# /afs/mpa/data/hitesh/envs/athenaenv/lib/python3.9/site-packages/matplotlib/cbook/__init__.py in __init__(self, exception_handler)
#     158     def __init__(self, exception_handler=_exception_printer):
#     159         self.exception_handler = exception_handler
# --> 160         self.callbacks = {}
#     161         self._cid_gen = itertools.count()
#     162         self._func_cid_map = {}
#
# KeyboardInterrupt:

# %%
import os

# dirname = 'test_sechs_Bx_cool'
# dirname = 'test_seben_By_cool'
# dirname = 'test_acht_Bz_cool'
# dirname = 'test_neun_hyd_cool'

# dirname = 'test_zehn_Bx_cool_reflBC'
# dirname = 'test_elf_By_cool_reflBC'
dirname = 'test_zwolf_Bz_cool_reflBC'
# dirname = 'test_dreizehn_hyd_cool_reflBC'

fig_save_dir = 'T'

cmd_mkdir = f'mkdir {dirname}/Plots/{fig_save_dir}'

os.system(cmd_mkdir)

M_lim = 30

for n in range(M_lim):

    file_name = dirname + f'/Turb.out2.{str(n).zfill(5)}.athdf'

    # print(ps.out_dt_arr[3]/ps.t_eddy[3])

    ds = yt.load(file_name)

    # p = yt.ProjectionPlot(ds,axis='x',fields="Bcc3")
    p = yt.SlicePlot(ds,axis='y',fields="temp")
    p.annotate_streamlines(('vel3'),('vel1'))

    p.set_figure_size(20)

    # p.set_zlim("press",5*1e-4, 1e-1)
    # p.set_zlim("vel3",-0.1,0.1)
#     p.set_zlim("vel3",0.001,0.1)
    # p.set_zlim("temp",4e4,4*1e6)
    p.set_zlim("temp",1e5,2e5)
    # p.set_zlim("density",1e-1, 1e2)

    p.save(dirname + f'/Plots/{fig_save_dir}/{fig_save_dir}_{str(n).zfill(5)}.png')

    # p.show()
# Out:
# yt : [WARNING  ] 2022-05-21 21:34:13,491 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:34:13,494 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:34:13,496 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:34:13,499 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:34:13,525 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-05-21 21:34:13,526 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:34:13,526 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:34:13,528 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:34:13,529 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:34:20,911 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:34:20,914 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:34:20,918 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:34:20,928 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:34:20,932 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:34:28,179 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00000.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:34:31,084 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:34:31,090 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:34:31,096 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:34:31,102 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:34:31,131 Parameters: current_time              = 1.0002837701780583
# yt : [INFO     ] 2022-05-21 21:34:31,133 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:34:31,134 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:34:31,135 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:34:31,137 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:34:38,675 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:34:38,677 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:34:38,682 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:34:38,685 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:34:38,690 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:34:46,312 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00001.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:34:50,378 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:34:50,382 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:34:50,387 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:34:50,392 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:34:50,424 Parameters: current_time              = 2.0004470084573573
# yt : [INFO     ] 2022-05-21 21:34:50,425 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:34:50,425 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:34:50,427 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:34:50,429 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:34:58,041 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:34:58,044 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:34:58,055 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:34:58,057 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:34:58,060 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:35:06,050 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00002.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:35:10,319 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:35:10,324 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:35:10,328 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:35:10,334 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:35:10,368 Parameters: current_time              = 3.000181160663157
# yt : [INFO     ] 2022-05-21 21:35:10,369 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:35:10,372 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:35:10,374 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:35:10,375 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:35:17,799 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:35:17,802 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:35:17,807 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:35:17,808 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:35:17,812 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:35:25,207 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00003.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:35:29,409 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:35:29,415 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:35:29,418 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:35:29,423 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:35:29,453 Parameters: current_time              = 4.000441315210067
# yt : [INFO     ] 2022-05-21 21:35:29,454 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:35:29,455 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:35:29,456 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:35:29,457 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:35:36,939 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:35:36,940 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:35:36,944 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:35:36,949 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:35:36,954 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:35:44,538 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00004.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:35:48,462 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:35:48,466 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:35:48,471 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:35:48,477 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:35:48,513 Parameters: current_time              = 5.000083154278135
# yt : [INFO     ] 2022-05-21 21:35:48,515 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:35:48,517 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:35:48,518 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:35:48,519 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:35:55,848 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:35:55,851 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:35:55,857 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:35:55,860 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:35:55,863 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:36:03,504 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00005.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:36:07,718 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:36:07,723 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:36:07,729 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:36:07,733 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:36:07,766 Parameters: current_time              = 6.000630288328617
# yt : [INFO     ] 2022-05-21 21:36:07,767 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:36:07,768 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:36:07,769 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:36:07,771 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:36:15,158 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:36:15,159 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:36:15,163 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:36:15,165 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:36:15,169 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:36:22,876 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00006.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:36:27,175 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:36:27,180 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:36:27,184 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:36:27,189 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:36:27,227 Parameters: current_time              = 7.0006847218107575
# yt : [INFO     ] 2022-05-21 21:36:27,228 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:36:27,230 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:36:27,233 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:36:27,236 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:36:34,741 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:36:34,743 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:36:34,754 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:36:34,758 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:36:34,759 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:36:42,411 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00007.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:36:46,564 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:36:46,569 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:36:46,576 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:36:46,582 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:36:46,617 Parameters: current_time              = 8.000165871695835
# yt : [INFO     ] 2022-05-21 21:36:46,619 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:36:46,621 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:36:46,622 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:36:46,624 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:36:54,085 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:36:54,088 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:36:54,093 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:36:54,095 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:36:54,099 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:37:01,787 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00008.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:37:05,693 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:37:05,698 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:37:05,705 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:37:05,714 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:37:05,740 Parameters: current_time              = 9.00090983586667
# yt : [INFO     ] 2022-05-21 21:37:05,741 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:37:05,744 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:37:05,746 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:37:05,747 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:37:13,133 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:37:13,136 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:37:13,140 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:37:13,144 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:37:13,147 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:37:20,695 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00009.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:37:25,016 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:37:25,022 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:37:25,029 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:37:25,034 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:37:25,065 Parameters: current_time              = 10.000876633896317
# yt : [INFO     ] 2022-05-21 21:37:25,065 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:37:25,066 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:37:25,067 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:37:25,068 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:37:32,427 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:37:32,430 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:37:32,434 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:37:32,441 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:37:32,446 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:37:40,198 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00010.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:37:44,324 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:37:44,329 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:37:44,333 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:37:44,338 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:37:44,370 Parameters: current_time              = 11.00028306992937
# yt : [INFO     ] 2022-05-21 21:37:44,371 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:37:44,373 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:37:44,375 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:37:44,378 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:37:51,769 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:37:51,773 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:37:51,780 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:37:51,783 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:37:51,788 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:37:59,289 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00011.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:38:03,559 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:38:03,565 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:38:03,573 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:38:03,578 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:38:03,605 Parameters: current_time              = 12.000133582213888
# yt : [INFO     ] 2022-05-21 21:38:03,605 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:38:03,606 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:38:03,607 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:38:03,608 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:38:10,920 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:38:10,923 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:38:10,926 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:38:10,930 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:38:10,934 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:38:18,252 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00012.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:38:22,331 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:38:22,337 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:38:22,342 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:38:22,347 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:38:22,409 Parameters: current_time              = 13.000698681137111
# yt : [INFO     ] 2022-05-21 21:38:22,410 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:38:22,412 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:38:22,415 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:38:22,416 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:38:29,643 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:38:29,645 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:38:29,650 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:38:29,653 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:38:29,658 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:38:37,104 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00013.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:38:41,587 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:38:41,592 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:38:41,596 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:38:41,601 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:38:41,627 Parameters: current_time              = 14.000281675218405
# yt : [INFO     ] 2022-05-21 21:38:41,628 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:38:41,630 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:38:41,631 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:38:41,632 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:38:48,941 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:38:48,944 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:38:48,949 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:38:48,953 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:38:48,957 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:38:56,241 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00014.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:39:00,359 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:39:00,363 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:39:00,366 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:39:00,370 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:39:00,411 Parameters: current_time              = 15.000681905742665
# yt : [INFO     ] 2022-05-21 21:39:00,412 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:39:00,413 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:39:00,415 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:39:00,415 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:39:07,955 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:39:07,958 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:39:07,965 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:39:07,970 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:39:07,973 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:39:15,252 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00015.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:39:19,364 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:39:19,369 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:39:19,375 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:39:19,380 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:39:19,410 Parameters: current_time              = 16.00022463100985
# yt : [INFO     ] 2022-05-21 21:39:19,410 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:39:19,411 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:39:19,412 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:39:19,415 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:39:26,657 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:39:26,659 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:39:26,664 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:39:26,667 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:39:26,673 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:39:34,193 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00016.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:39:38,464 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:39:38,468 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:39:38,474 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:39:38,481 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:39:38,509 Parameters: current_time              = 17.000866164394488
# yt : [INFO     ] 2022-05-21 21:39:38,510 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:39:38,511 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:39:38,512 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:39:38,513 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:39:46,202 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:39:46,204 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:39:46,211 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:39:46,217 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:39:46,221 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:39:53,934 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00017.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:39:57,939 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:39:57,943 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:39:57,949 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:39:57,954 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:39:57,987 Parameters: current_time              = 18.000212497321264
# yt : [INFO     ] 2022-05-21 21:39:57,988 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:39:57,988 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:39:57,990 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:39:57,991 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:40:05,409 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:40:05,411 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:40:05,416 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:40:05,422 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:40:05,429 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:40:13,019 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00018.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:40:17,057 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:40:17,061 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:40:17,066 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:40:17,072 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:40:17,104 Parameters: current_time              = 19.000851582140513
# yt : [INFO     ] 2022-05-21 21:40:17,105 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:40:17,105 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:40:17,106 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:40:17,107 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:40:24,532 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:40:24,534 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:40:24,537 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:40:24,540 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:40:24,542 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:40:31,985 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00019.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:40:36,191 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:40:36,196 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:40:36,201 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:40:36,205 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:40:36,236 Parameters: current_time              = 20.00020558850212
# yt : [INFO     ] 2022-05-21 21:40:36,237 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:40:36,238 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:40:36,240 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:40:36,242 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:40:43,751 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:40:43,753 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:40:43,756 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:40:43,759 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:40:43,762 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:40:51,250 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00020.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:40:55,398 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:40:55,405 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:40:55,409 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:40:55,417 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:40:55,449 Parameters: current_time              = 21.001004256730063
# yt : [INFO     ] 2022-05-21 21:40:55,450 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:40:55,451 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:40:55,452 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:40:55,453 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:41:03,641 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:41:03,644 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:41:03,649 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:41:03,652 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:41:03,656 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:41:11,384 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00021.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [WARNING  ] 2022-05-21 21:41:15,528 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-21 21:41:15,532 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-21 21:41:15,536 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-21 21:41:15,540 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-21 21:41:15,573 Parameters: current_time              = 22.000499337460948
# yt : [INFO     ] 2022-05-21 21:41:15,574 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-21 21:41:15,575 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-21 21:41:15,578 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-21 21:41:15,578 Parameters: cosmological_simulation   = 0.0
# yt : [INFO     ] 2022-05-21 21:41:22,943 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:41:22,947 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:41:22,951 xlim = -0.100000 0.900000
# yt : [INFO     ] 2022-05-21 21:41:22,955 ylim = 0.000000 0.100000
# yt : [INFO     ] 2022-05-21 21:41:22,958 Making a fixed resolution buffer of (('gas', 'temp')) 800 by 800
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:255: MatplotlibDeprecationWarning: Passing parameters norm and vmin/vmax simultaneously is deprecated since 3.3 and will become an error two minor releases later. Please pass vmin/vmax directly to the norm when creating it.
#   self.image = self.axes.imshow(
# yt : [INFO     ] 2022-05-21 21:41:30,475 Saving plot test_zwolf_Bz_cool_reflBC/Plots/T/T_00022.png
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
#   self[key] = other[key]
# /home/hitesh/miniconda3/envs/mainenv/lib/python3.9/_collections_abc.py:941: MatplotlibDeprecationWarning:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   self[key] = other[key]
# /home/hitesh/.local/lib/python3.9/site-packages/yt/visualization/base_plot_types.py:163: MatplotlibDeprecationWarning: print_figure() got unexpected keyword argument "papertype" which is no longer supported as of 3.3 and will become an error two minor releases later
#   canvas.print_figure(name, **mpl_kwargs)
# yt : [ERROR    ] 2022-05-21 21:41:31,118 None of the arguments provided to load() is a valid file
# yt : [ERROR    ] 2022-05-21 21:41:31,122 Please check that you have used a correct path
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-49-d05a83253bd3> in <module>
#      25     # print(ps.out_dt_arr[3]/ps.t_eddy[3])
#      26
# ---> 27     ds = yt.load(file_name)
#      28
#      29     # p = yt.ProjectionPlot(ds,axis='x',fields="Bcc3")
#
# ~/.local/lib/python3.9/site-packages/yt/convenience.py in load(*args, **kwargs)
#      74             mylog.error("None of the arguments provided to load() is a valid file")
#      75             mylog.error("Please check that you have used a correct path")
# ---> 76             raise YTOutputNotIdentified(args, kwargs)
#      77     for n, c in types_to_check.items():
#      78         if n is None: continue
#
# YTOutputNotIdentified: Supplied ('test_zwolf_Bz_cool_reflBC/Turb.out2.00023.athdf',) {}, but could not load!

# %%
# dirname = 'test_sechs_Bx_cool'
# dirname = 'test_seben_By_cool'
# dirname = 'test_acht_Bz_cool'
# dirname = 'test_neun_hyd_cool'

# dirname = 'test_zehn_Bx_cool_reflBC'
# dirname = 'test_elf_By_cool_reflBC'
dirname = 'test_zwolf_Bz_cool_reflBC'
# dirname = 'test_dreizehn_hyd_cool_reflBC'

fig_save_dir = 'T'
framerate    = 5


cmd_cd    = f'cd {dirname}/Plots/{fig_save_dir}'
cmd_vid   = f'ffmpeg -framerate {framerate} -i {fig_save_dir}_%05d.png {fig_save_dir}.mp4'
cmd_fin   = f'cd ../../..'

command_list = [cmd_cd,cmd_vid,cmd_fin]

command = " && ".join(command_list)

print(command)

os.system(command)
# Out:
# cd test_zwolf_Bz_cool_reflBC/Plots/T && ffmpeg -framerate 5 -i T_%05d.png T.mp4 && cd ../../..
# 0

# %%
n1 = 64
n2 = 64
n3 = 320

# dirname = 'test_sechs_Bx_cool'
# dirname = 'test_seben_By_cool'
# dirname = 'test_acht_Bz_cool'
# dirname = 'test_neun_hyd_cool'

# dirname = 'test_neun_hyd_cool'
dirname = 'test_dreizehn_hyd_cool_reflBC'

hst = hst_data(dirname+'/Turb.hst',ncells=n1*n2*n3)
plt.plot(hst.time,hst.mass_tot, linestyle='dashed', label='hydro')
plt.plot(hst.time,hst.cold_gas, label='hydro')

# dirname = 'test_sechs_Bx_cool'
# hst = hst_data(dirname+'/Turb.hst',ncells=n1*n2*n3)
# plt.plot(hst.time,hst.mass_tot, linestyle='dashed', label='B_x')
# plt.plot(hst.time,hst.cold_gas, label='B_x')

# dirname = 'test_seben_By_cool'
# hst = hst_data(dirname+'/Turb.hst',ncells=n1*n2*n3)
# plt.plot(hst.time,hst.mass_tot, linestyle='dashed', label='B_y')
# plt.plot(hst.time,hst.cold_gas, label='B_y')

# dirname = 'test_acht_Bz_cool'
dirname = 'test_zwolf_Bz_cool_reflBC'
hst = hst_data(dirname+'/Turb.hst',ncells=n1*n2*n3)
plt.plot(hst.time,hst.mass_tot, linestyle='dashed', label='B_z')
plt.plot(hst.time,hst.cold_gas, label='B_z')

# plt.xlim(0,51)

# plt.yscale('log')

plt.legend()

# %%
# dirname = 'test_sechs_Bx_cool'
# dirname = 'test_seben_By_cool'
dirname = 'test_acht_Bz_cool'
# dirname = 'test_neun_hyd_cool'

N  = 0
dN = 1

file_name_0 = dirname + f'/Turb.out2.{str(N+0*dN).zfill(5)}.athdf'
file_name_1 = dirname + f'/Turb.out2.{str(N+1*dN).zfill(5)}.athdf'
file_name_2 = dirname + f'/Turb.out2.{str(N+2*dN).zfill(5)}.athdf'
file_name_3 = dirname + f'/Turb.out2.{str(N+3*dN).zfill(5)}.athdf'

MHD = True

out_dict_0 = get_array(file_name_0, MHD_flag=MHD)
out_dict_1 = get_array(file_name_1, MHD_flag=MHD)
out_dict_2 = get_array(file_name_2, MHD_flag=MHD)
out_dict_3 = get_array(file_name_3, MHD_flag=MHD)
# Out:
# yt : [ERROR    ] 2022-05-21 03:43:57,512 None of the arguments provided to load() is a valid file
# yt : [ERROR    ] 2022-05-21 03:43:57,515 Please check that you have used a correct path
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-27-f0660fc425d4> in <module>
#      14 MHD = True
#      15
# ---> 16 out_dict_0 = get_array(file_name_0, MHD_flag=MHD)
#      17 out_dict_1 = get_array(file_name_1, MHD_flag=MHD)
#      18 out_dict_2 = get_array(file_name_2, MHD_flag=MHD)
#
# <ipython-input-3-09a212da9748> in get_array(fn, MHD_flag)
#       1 def get_array(fn, MHD_flag = False):
#       2
# ----> 3     ds = yt.load(fn)
#       4
#       5     all_data_level_0_hyd = ds.covering_grid(
#
# ~/.local/lib/python3.9/site-packages/yt/convenience.py in load(*args, **kwargs)
#      74             mylog.error("None of the arguments provided to load() is a valid file")
#      75             mylog.error("Please check that you have used a correct path")
# ---> 76             raise YTOutputNotIdentified(args, kwargs)
#      77     for n, c in types_to_check.items():
#      78         if n is None: continue
#
# YTOutputNotIdentified: Supplied ('test_acht_Bz_cool/Turb.out2.00000.athdf',) {}, but could not load!

# %%
hist_T = np.histogram(out_dict_0['T'],bins=10000)#, weights=out_dict_0['rho'])
plt.plot(hist_T[1][:-1], hist_T[0], label=f'{N+0*dN}')

hist_T = np.histogram(out_dict_1['T'],bins=10000)#, weights=out_dict_1['rho'])
plt.plot(hist_T[1][:-1], hist_T[0], label=f'{N+1*dN}')

hist_T = np.histogram(out_dict_2['T'],bins=10000)#, weights=out_dict_2['rho'])
plt.plot(hist_T[1][:-1], hist_T[0], label=f'{N+2*dN}')

hist_T = np.histogram(out_dict_3['T'],bins=10000)#, weights=out_dict_3['rho'])
plt.plot(hist_T[1][:-1], hist_T[0], label=f'{N+3*dN}')

plt.xlim(1e4, 1e7)
# plt.xlim(1e-4, 1e-1)

plt.axvline(0.25*4000000, linestyle='dashed')

plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
def arr_arrange(A):
    N = np.shape(A)[0]
    # A_2 = np.zeros_like(A)

    return np.flip(np.transpose(A),axis=0)

# plot_arr = out_dict_0['coord'][1][32,:,:]
plot_arr = out_dict_0['rho'][:,32,:]
# plot_arr = arr_arrange(plot_arr)
plt.figure()
plt.imshow(plot_arr)
plt.colorbar()


plot_arr = out_dict_0['coord'][2][:,32,:]
plt.figure()
plt.imshow(plot_arr)
plt.colorbar()

# %%
# dirname = 'test_sechs_Bx_cool'
# dirname = 'test_seben_By_cool'
# dirname = 'test_acht_Bz_cool'
dirname = 'test_neun_hyd_cool'

t_list   = []
mix_list = []

for N in range(25):
    file_name_0 = dirname + f'/Turb.out2.{str(N).zfill(5)}.athdf'
    out_dict_0 = get_array(file_name_0) #, MHD_flag=MHD)


    cond = np.logical_and(out_dict_0['T']>1e5, out_dict_0['T']<2e5)

    mix_mass = np.sum(out_dict_0['rho'][cond])

    # print(mix_mass)
    t_list.append(N)
    mix_list.append(np.sum(out_dict_0['rho'][cond]))

print
# Out:
# yt : [WARNING  ] 2022-05-19 14:44:29,211 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:44:29,212 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:44:29,213 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:44:29,214 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:44:29,225 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-05-19 14:44:29,226 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:44:29,227 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:44:29,228 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:44:29,229 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:44:33,820 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:44:33,823 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:44:33,826 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:44:33,829 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:44:33,848 Parameters: current_time              = 1.0002415746760216
# yt : [INFO     ] 2022-05-19 14:44:33,849 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:44:33,850 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:44:33,851 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:44:33,853 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:44:38,552 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:44:38,553 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:44:38,556 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:44:38,559 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:44:38,577 Parameters: current_time              = 2.000861332171227
# yt : [INFO     ] 2022-05-19 14:44:38,577 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:44:38,578 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:44:38,579 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:44:38,582 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:44:43,024 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:44:43,026 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:44:43,027 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:44:43,030 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:44:43,047 Parameters: current_time              = 3.0005255568173603
# yt : [INFO     ] 2022-05-19 14:44:43,048 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:44:43,048 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:44:43,049 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:44:43,055 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:44:47,514 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:44:47,517 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:44:47,520 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:44:47,521 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:44:47,542 Parameters: current_time              = 4.000477587811493
# yt : [INFO     ] 2022-05-19 14:44:47,542 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:44:47,543 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:44:47,545 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:44:47,546 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:44:51,842 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:44:51,844 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:44:51,844 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:44:51,845 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:44:51,860 Parameters: current_time              = 5.00030294471051
# yt : [INFO     ] 2022-05-19 14:44:51,863 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:44:51,866 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:44:51,868 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:44:51,870 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:44:56,387 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:44:56,388 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:44:56,389 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:44:56,390 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:44:56,409 Parameters: current_time              = 6.000391083263135
# yt : [INFO     ] 2022-05-19 14:44:56,410 Parameters: domain_dimensions         = [ 64  64 320]
# yt : [INFO     ] 2022-05-19 14:44:56,411 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:44:56,415 Parameters: domain_right_edge         = [0.1 0.1 0.4]
# yt : [INFO     ] 2022-05-19 14:44:56,422 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:44:59,194 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:44:59,195 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:44:59,198 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:44:59,203 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:44:59,225 Parameters: current_time              = 7.00067262000748
# yt : [INFO     ] 2022-05-19 14:44:59,225 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:44:59,226 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:44:59,226 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:44:59,227 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:03,609 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:03,610 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:03,611 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:03,612 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:03,632 Parameters: current_time              = 8.00012073649771
# yt : [INFO     ] 2022-05-19 14:45:03,633 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:03,636 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:03,640 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:03,642 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:07,997 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:07,999 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:08,000 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:08,001 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:08,019 Parameters: current_time              = 9.00044991293537
# yt : [INFO     ] 2022-05-19 14:45:08,020 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:08,021 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:08,022 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:08,024 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:12,221 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:12,222 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:12,223 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:12,224 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:12,245 Parameters: current_time              = 10.000599389065338
# yt : [INFO     ] 2022-05-19 14:45:12,247 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:12,251 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:12,253 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:12,255 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:17,122 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:17,123 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:17,124 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:17,125 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:17,149 Parameters: current_time              = 11.000082454601971
# yt : [INFO     ] 2022-05-19 14:45:17,151 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:17,152 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:17,154 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:17,156 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:21,428 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:21,429 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:21,432 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:21,436 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:21,458 Parameters: current_time              = 12.00038970053567
# yt : [INFO     ] 2022-05-19 14:45:21,459 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:21,459 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:21,461 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:21,463 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:25,707 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:25,708 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:25,710 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:25,712 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:25,740 Parameters: current_time              = 13.000735139243334
# yt : [INFO     ] 2022-05-19 14:45:25,740 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:25,742 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:25,743 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:25,745 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:30,034 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:30,034 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:30,035 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:30,036 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:30,055 Parameters: current_time              = 14.000844136948153
# yt : [INFO     ] 2022-05-19 14:45:30,056 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:30,056 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:30,062 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:30,064 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:34,389 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:34,390 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:34,390 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:34,391 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:34,416 Parameters: current_time              = 15.000039678832028
# yt : [INFO     ] 2022-05-19 14:45:34,418 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:34,419 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:34,422 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:34,422 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:38,960 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:38,963 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:38,967 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:38,972 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:38,991 Parameters: current_time              = 16.000813717926178
# yt : [INFO     ] 2022-05-19 14:45:38,992 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:38,993 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:38,994 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:38,998 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:43,441 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:43,443 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:43,444 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:43,446 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:43,465 Parameters: current_time              = 17.00031737340942
# yt : [INFO     ] 2022-05-19 14:45:43,467 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:43,470 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:43,473 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:43,475 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:47,756 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:47,758 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:47,759 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:47,762 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:47,780 Parameters: current_time              = 18.00000621109671
# yt : [INFO     ] 2022-05-19 14:45:47,781 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:47,782 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:47,783 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:47,792 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:51,946 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:51,947 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:51,949 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:51,952 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:51,974 Parameters: current_time              = 19.000776524072155
# yt : [INFO     ] 2022-05-19 14:45:51,974 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:51,974 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:51,975 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:51,977 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:45:56,732 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:45:56,734 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:45:56,736 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:45:56,738 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:45:56,756 Parameters: current_time              = 20.0006881257853
# yt : [INFO     ] 2022-05-19 14:45:56,757 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:45:56,758 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:45:56,760 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:45:56,765 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:46:01,286 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:46:01,287 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:46:01,289 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:46:01,290 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:46:01,309 Parameters: current_time              = 21.000483334634453
# yt : [INFO     ] 2022-05-19 14:46:01,310 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:46:01,313 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:46:01,320 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:46:01,322 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:46:05,675 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:46:05,676 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:46:05,678 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:46:05,679 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:46:05,701 Parameters: current_time              = 22.000039140691783
# yt : [INFO     ] 2022-05-19 14:46:05,703 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:46:05,706 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:46:05,708 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:46:05,710 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:46:10,213 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:46:10,214 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:46:10,215 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:46:10,217 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:46:10,236 Parameters: current_time              = 23.000168090885897
# yt : [INFO     ] 2022-05-19 14:46:10,236 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:46:10,237 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:46:10,239 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:46:10,246 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2022-05-19 14:46:14,542 Assuming 1.0 = 1.0 cm
# yt : [WARNING  ] 2022-05-19 14:46:14,543 Assuming 1.0 = 1.0 s
# yt : [WARNING  ] 2022-05-19 14:46:14,545 Assuming 1.0 = 1.0 g
# yt : [WARNING  ] 2022-05-19 14:46:14,547 Assuming 1.0 = 1.0 K
# yt : [INFO     ] 2022-05-19 14:46:14,568 Parameters: current_time              = 24.000080465190308
# yt : [INFO     ] 2022-05-19 14:46:14,568 Parameters: domain_dimensions         = [ 64  64 640]
# yt : [INFO     ] 2022-05-19 14:46:14,570 Parameters: domain_left_edge          = [ 0.   0.  -0.1]
# yt : [INFO     ] 2022-05-19 14:46:14,571 Parameters: domain_right_edge         = [0.1 0.1 0.9]
# yt : [INFO     ] 2022-05-19 14:46:14,572 Parameters: cosmological_simulation   = 0.0
# <function print>

# %%
plt.plot(t_list, mix_list)
plt.yscale('log')

# %%
np.min(out_dict_3['P'])
# Out:
# 0.0011549248297283194
